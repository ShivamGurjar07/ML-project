# %%
#Loading liberiers
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# c:\Users\91756\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#Reading train files
df1=pd.read_csv("twitter_training.csv",encoding='ISO-8859-1')
df1.columns=['id','location','target','text']
df1
# Out:
#          id             location      target  \
# 0      2401          Borderlands    Positive
# 1      2401          Borderlands    Positive
# 2      2401          Borderlands    Positive
# 3      2401          Borderlands    Positive
# 4      2401          Borderlands    Positive
# ...     ...                  ...         ...
# 75676  4891  GrandTheftAuto(GTA)  Irrelevant
# 75677  4359                CS-GO  Irrelevant
# 75678  2652          Borderlands    Positive
# 75679  8069            Microsoft    Positive
# 75680  6960      johnson&johnson     Neutral
#
#                                                     text
# 0      I am coming to the borders and I will kill you...
# 1      im getting on borderlands and i will kill you ...
# 2      im coming on borderlands and i will murder you...
# 3      im getting on borderlands 2 and i will murder ...
# 4      im getting into borderlands and i can murder y...
# ...                                                  ...
# ...

# %%
#Reading Validation  files
df2=pd.read_csv("twitter_validation.csv",encoding='ISO-8859-1')
df2.columns=['id','location','target','text']
df2
# Out:
#        id             location      target  \
# 0     352               Amazon     Neutral
# 1    8312            Microsoft    Negative
# 2    4371                CS-GO    Negative
# 3    4433               Google     Neutral
# 4    6273                 FIFA    Negative
# ..    ...                  ...         ...
# 994  4891  GrandTheftAuto(GTA)  Irrelevant
# 995  4359                CS-GO  Irrelevant
# 996  2652          Borderlands    Positive
# 997  8069            Microsoft    Positive
# 998  6960      johnson&johnson     Neutral
#
#                                                   text
# 0    BBC News - Amazon boss Jeff Bezos rejects clai...
# 1    @Microsoft Why do I pay for WORD when it funct...
# 2    CSGO matchmaking is so full of closet hacking,...
# 3    Now the President is slapping Americans in the...
# 4    Hi @EAHelp Iâve had Madeleine McCann in my c...
# ..                                                 ...
# ...

# %%
#Merging Both files for preprocessing
df= pd.concat([df1,df2])
df
# Out:
#        id             location      target  \
# 0    2401          Borderlands    Positive
# 1    2401          Borderlands    Positive
# 2    2401          Borderlands    Positive
# 3    2401          Borderlands    Positive
# 4    2401          Borderlands    Positive
# ..    ...                  ...         ...
# 994  4891  GrandTheftAuto(GTA)  Irrelevant
# 995  4359                CS-GO  Irrelevant
# 996  2652          Borderlands    Positive
# 997  8069            Microsoft    Positive
# 998  6960      johnson&johnson     Neutral
#
#                                                   text
# 0    I am coming to the borders and I will kill you...
# 1    im getting on borderlands and i will kill you ...
# 2    im coming on borderlands and i will murder you...
# 3    im getting on borderlands 2 and i will murder ...
# 4    im getting into borderlands and i can murder y...
# ..                                                 ...
# ...

# %%
filtered_df_positive = df[(df['text'].str.contains('game', case=False)) & (df['target'] == 'Positive')]
filtered_df_positive
# Out:
#         id              location    target  \
# 119   2421           Borderlands  Positive
# 120   2421           Borderlands  Positive
# 122   2421           Borderlands  Positive
# 123   2421           Borderlands  Positive
# 124   2421           Borderlands  Positive
# ..     ...                   ...       ...
# 881   5598           Hearthstone  Positive
# 903   3946         Cyberpunk2077  Positive
# 910   1088        AssassinsCreed  Positive
# 967   1264           Battlefield  Positive
# 989  11504  TomClancysRainbowSix  Positive
#
#                                                   text
# 119  Finally played through borderlands 3. The actu...
# 120  Finally played by Borderlands 3. The actual ga...
# 122  Finally played through borderlands 3. The open...
# 123  Finally played through borderlands 3. The actu...
# 124  Finally played through borderlands 5. The actu...
# ..                                                 ...
# ...

# %%
filtered_df_negative = df[(df['text'].str.contains('game', case=False)) & (df['target'] == 'Negative')]
filtered_df_negative
# Out:
#         id              location    target  \
# 95    2417           Borderlands  Negative
# 96    2417           Borderlands  Negative
# 97    2417           Borderlands  Negative
# 98    2417           Borderlands  Negative
# 99    2417           Borderlands  Negative
# ..     ...                   ...       ...
# 843   2049            CallOfDuty  Negative
# 859   7272       LeagueOfLegends  Negative
# 883  11269  TomClancysRainbowSix  Negative
# 978  11431  TomClancysRainbowSix  Negative
# 983   1373           Battlefield  Negative
#
#                                                   text
# 95   Grounded almost looked pretty cool even despit...
# 96   Grounded looked cool despite the borderline un...
# 97   Grosskreutz looked pretty cool, even despite t...
# 98   Grounded almost looked pretty cool here despit...
# 99   Deep Grounded almost looked pretty cool even d...
# ..                                                 ...
# ...

# %%
filtered_df_neutral = df[(df['text'].str.contains('game', case=False)) & (df['target'] == 'Neutral')]
filtered_df_neutral
# Out:
#         id              location   target  \
# 89    2416           Borderlands  Neutral
# 90    2416           Borderlands  Neutral
# 91    2416           Borderlands  Neutral
# 92    2416           Borderlands  Neutral
# 93    2416           Borderlands  Neutral
# ..     ...                   ...      ...
# 855    220                Amazon  Neutral
# 856  11613               Verizon  Neutral
# 869   4235                 CS-GO  Neutral
# 947  11463  TomClancysRainbowSix  Neutral
# 948    353                Amazon  Neutral
#
#                                                   text
# 89   I hate that this easy mayhem modifier event on...
# 90   I hate that this simple Chaos Modifier event o...
# 91   I hate that this easy mayhem modifier event on...
# 92   I hate saying this easy day 9 event on mayhem ...
# 93   I hate thinking that this easy mayhem modifier...
# ..                                                 ...
# 855  I played this interesting quiz on Amazon - Try...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76680 entries, 0 to 998
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        76680 non-null  int64
#  1   location  76680 non-null  object
#  2   target    76680 non-null  object
#  3   text      75994 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.9+ MB

# %%
df['text'] = df['text'].astype('string')

# %%
# checking data Types of colums
df.dtypes
# Out:
# id           int64
# location    object
# target      object
# text        string
# dtype: object

# %%
#Total no of rows and columns
df.shape
# Out:
# (76680, 4)

# %%
#Checking NA values
df.isna().sum()
# Out:
# id            0
# location      0
# target        0
# text        686
# dtype: int64

# %%
#removing NA values
df.dropna(inplace=True)

# %%
#Again Checking NA values
df.isna().sum()
# Out:
# id          0
# location    0
# target      0
# text        0
# dtype: int64

# %%
df['location'].value_counts()
# Out:
# LeagueOfLegends                      2451
# CallOfDuty                           2438
# MaddenNFL                            2435
# TomClancysRainbowSix                 2434
# Verizon                              2429
# Facebook                             2427
# ApexLegends                          2425
# WorldOfCraft                         2417
# Microsoft                            2417
# Dota2                                2413
# johnson&johnson                      2402
# FIFA                                 2400
# CallOfDutyBlackopsColdWar            2397
# NBA2K                                2385
# Overwatch                            2380
# Battlefield                          2368
# TomClancysGhostRecon                 2365
# GrandTheftAuto(GTA)                  2363
# PlayStation5(PS5)                    2357
# Hearthstone                          2350
# CS-GO                                2348
# Borderlands                          2345
# ...

# %%
df['target'].value_counts()
# Out:
# Negative      22890
# Positive      21208
# Neutral       18678
# Irrelevant    13218
# Name: target, dtype: int64

# %%
df['location'].unique()
# Out:
# array(['Borderlands', 'CallOfDutyBlackopsColdWar', 'Amazon', 'Overwatch',
#        'Xbox(Xseries)', 'NBA2K', 'Dota2', 'PlayStation5(PS5)',
#        'WorldOfCraft', 'CS-GO', 'Google', 'AssassinsCreed', 'ApexLegends',
#        'LeagueOfLegends', 'Fortnite', 'Microsoft', 'Hearthstone',
#        'Battlefield', 'PlayerUnknownsBattlegrounds(PUBG)', 'Verizon',
#        'HomeDepot', 'FIFA', 'RedDeadRedemption(RDR)', 'CallOfDuty',
#        'TomClancysRainbowSix', 'Facebook', 'GrandTheftAuto(GTA)',
#        'MaddenNFL', 'johnson&johnson', 'Cyberpunk2077',
#        'TomClancysGhostRecon', 'Nvidia'], dtype=object)

# %%
sns.countplot(x='target',data=df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, y="location", order=df["location"].value_counts().index[:25])
# Out:
# <AxesSubplot:xlabel='count', ylabel='location'>

# %%
df.drop(df.index[(df['target']=='Irrelevant')],axis=0,inplace=True)
df
# Out:
#        id           location    target  \
# 0    2401        Borderlands  Positive
# 1    2401        Borderlands  Positive
# 2    2401        Borderlands  Positive
# 3    2401        Borderlands  Positive
# 4    2401        Borderlands  Positive
# ..    ...                ...       ...
# 992   314             Amazon  Negative
# 993  9701  PlayStation5(PS5)  Positive
# 996  2652        Borderlands  Positive
# 997  8069          Microsoft  Positive
# 998  6960    johnson&johnson   Neutral
#
#                                                   text
# 0    I am coming to the borders and I will kill you...
# 1    im getting on borderlands and i will kill you ...
# 2    im coming on borderlands and i will murder you...
# 3    im getting on borderlands 2 and i will murder ...
# 4    im getting into borderlands and i can murder y...
# ..                                                 ...
# 992  Please explain how this is possible! How can t...
# ...

# %%
#reset index
df.reset_index(drop=True,inplace=True)
df
# Out:
#          id           location    target  \
# 0      2401        Borderlands  Positive
# 1      2401        Borderlands  Positive
# 2      2401        Borderlands  Positive
# 3      2401        Borderlands  Positive
# 4      2401        Borderlands  Positive
# ...     ...                ...       ...
# 62536   314             Amazon  Negative
# 62537  9701  PlayStation5(PS5)  Positive
# 62538  2652        Borderlands  Positive
# 62539  8069          Microsoft  Positive
# 62540  6960    johnson&johnson   Neutral
#
#                                                     text
# 0      I am coming to the borders and I will kill you...
# 1      im getting on borderlands and i will kill you ...
# 2      im coming on borderlands and i will murder you...
# 3      im getting on borderlands 2 and i will murder ...
# 4      im getting into borderlands and i can murder y...
# ...                                                  ...
# 62536  Please explain how this is possible! How can t...
# ...

# %%
#pie chart 
k=df["target"].value_counts()
myexplode = [0.1, 0, 0]
plt.pie(k.values,autopct='%1.1f%%',labels=k.index,explode=myexplode,shadow=True)

plt.show()

# %%
df.drop(['id','location'],axis=1,inplace = True)
df
# Out:
#          target                                               text
# 0      Positive  I am coming to the borders and I will kill you...
# 1      Positive  im getting on borderlands and i will kill you ...
# 2      Positive  im coming on borderlands and i will murder you...
# 3      Positive  im getting on borderlands 2 and i will murder ...
# 4      Positive  im getting into borderlands and i can murder y...
# ...         ...                                                ...
# 62536  Negative  Please explain how this is possible! How can t...
# 62537  Positive  Good on Sony. As much as I want to see the new...
# 62538  Positive  Today sucked so itâs time to drink wine n pl...
# 62539  Positive  Bought a fraction of Microsoft today. Small wins.
# 62540   Neutral  Johnson & Johnson to stop selling talc baby po...
#
# [62541 rows x 2 columns]

# %%
df['target'] = df['target'].replace(['Neutral','Positive','Negative'], [0,1,-1])
df
# Out:
#        target                                               text
# 0           1  I am coming to the borders and I will kill you...
# 1           1  im getting on borderlands and i will kill you ...
# 2           1  im coming on borderlands and i will murder you...
# 3           1  im getting on borderlands 2 and i will murder ...
# 4           1  im getting into borderlands and i can murder y...
# ...       ...                                                ...
# 62536      -1  Please explain how this is possible! How can t...
# 62537       1  Good on Sony. As much as I want to see the new...
# 62538       1  Today sucked so itâs time to drink wine n pl...
# 62539       1  Bought a fraction of Microsoft today. Small wins.
# 62540       0  Johnson & Johnson to stop selling talc baby po...
#
# [62541 rows x 2 columns]

# %%
df.dtypes
# Out:
# target     int64
# text      string
# dtype: object

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\91756\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\91756\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\91756\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\91756\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from wordcloud import WordCloud

# %%
positive_tweets = df[df['target'] == 1]
negative_tweets = df[df['target'] == -1]
neutral_tweets = df[df['target'] == 0]

# %%
# Concatenate the text from each dataframe
positive_text = ' '.join(positive_tweets['text'].astype(str))
negative_text = ' '.join(negative_tweets['text'].astype(str))
neutral_text = ' '.join(neutral_tweets['text'].astype(str))

# %%
tweets=df.text
tweets
# Out:
# 0        I am coming to the borders and I will kill you...
# 1        im getting on borderlands and i will kill you ...
# 2        im coming on borderlands and i will murder you...
# 3        im getting on borderlands 2 and i will murder ...
# 4        im getting into borderlands and i can murder y...
#                                ...
# 62536    Please explain how this is possible! How can t...
# 62537    Good on Sony. As much as I want to see the new...
# 62538    Today sucked so itâs time to drink wine n pl...
# 62539    Bought a fraction of Microsoft today. Small wins.
# 62540    Johnson & Johnson to stop selling talc baby po...
# Name: text, Length: 62541, dtype: string

# %%
#creating sentences into tokens
from nltk.tokenize import TweetTokenizer
tk=TweetTokenizer()
tweets=tweets.apply(lambda x:tk.tokenize(x)).apply(lambda x:" ".join(x))
tweets
# Out:
# 0        I am coming to the borders and I will kill you...
# 1        im getting on borderlands and i will kill you ...
# 2        im coming on borderlands and i will murder you...
# 3        im getting on borderlands 2 and i will murder ...
# 4        im getting into borderlands and i can murder y...
#                                ...
# 62536    Please explain how this is possible ! How can ...
# 62537    Good on Sony . As much as I want to see the ne...
# 62538    Today sucked so itâ   s time to drink wine n...
# 62539    Bought a fraction of Microsoft today . Small w...
# 62540    Johnson & Johnson to stop selling talc baby po...
# Name: text, Length: 62541, dtype: object

# %%
#remove special charters
tweets=tweets.str.replace('[^a-z A-Z 0-9]+',' ')
tweets
# Out:
# C:\Users\91756\AppData\Local\Temp\ipykernel_37736\2011903881.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   tweets=tweets.str.replace('[^a-z A-Z 0-9]+',' ')
# 0        I am coming to the borders and I will kill you...
# 1        im getting on borderlands and i will kill you ...
# 2        im coming on borderlands and i will murder you...
# 3        im getting on borderlands 2 and i will murder ...
# 4        im getting into borderlands and i can murder y...
#                                ...
# 62536    Please explain how this is possible   How can ...
# 62537    Good on Sony   As much as I want to see the ne...
# 62538    Today sucked so it      s time to drink wine n...
# 62539    Bought a fraction of Microsoft today   Small w...
# 62540    Johnson   Johnson to stop selling talc baby po...
# Name: text, Length: 62541, dtype: object

# %%
#stemming
from nltk.stem import SnowballStemmer
ss = SnowballStemmer('english')
tweets = tweets.apply(lambda x:[ss.stem(i.lower()) for i in tk.tokenize(x)]).apply(lambda x:' '.join(x))
tweets
# Out:
# 0          i am come to the border and i will kill you all
# 1             im get on borderland and i will kill you all
# 2          im come on borderland and i will murder you all
# 3        im get on borderland 2 and i will murder you m...
# 4          im get into borderland and i can murder you all
#                                ...
# 62536    pleas explain how this is possibl how can they...
# 62537    good on soni as much as i want to see the new ...
# 62538    today suck so it s time to drink wine n play b...
# 62539       bought a fraction of microsoft today small win
# 62540    johnson johnson to stop sell talc babi powder ...
# Name: text, Length: 62541, dtype: object

# %%
#removing stopwords
from nltk.corpus import stopwords
sw=stopwords.words('english')
tweets = tweets.apply(lambda x:[i for i in tk.tokenize(x) if  i not in sw]).apply(lambda x:' '.join(x))
tweets
# Out:
# 0                                         come border kill
# 1                                   im get borderland kill
# 2                                im come borderland murder
# 3                               im get borderland 2 murder
# 4                                 im get borderland murder
#                                ...
# 62536    pleas explain possibl let compani overcharg sc...
# 62537    good soni much want see new ps5 go right much ...
# 62538    today suck time drink wine n play borderland s...
# 62539            bought fraction microsoft today small win
# 62540    johnson johnson stop sell talc babi powder u c...
# Name: text, Length: 62541, dtype: object

# %%
df["clean_text"]=tweets
df
# Out:
#        target                                               text  \
# 0           1  I am coming to the borders and I will kill you...
# 1           1  im getting on borderlands and i will kill you ...
# 2           1  im coming on borderlands and i will murder you...
# 3           1  im getting on borderlands 2 and i will murder ...
# 4           1  im getting into borderlands and i can murder y...
# ...       ...                                                ...
# 62536      -1  Please explain how this is possible! How can t...
# 62537       1  Good on Sony. As much as I want to see the new...
# 62538       1  Today sucked so itâs time to drink wine n pl...
# 62539       1  Bought a fraction of Microsoft today. Small wins.
# 62540       0  Johnson & Johnson to stop selling talc baby po...
#
#                                               clean_text
# 0                                       come border kill
# 1                                 im get borderland kill
# ...

# %%
#wordcloud of postitive tweets
wordcloud = WordCloud(width=800, height=400).generate(positive_text)
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#wordcloud of Negative  tweets
wordcloud = WordCloud(width=800, height=400).generate(negative_text)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#wordcloud of neutral tweets
wordcloud = WordCloud(width=800, height=400).generate(neutral_text)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#vectorization
from sklearn.feature_extraction.text import TfidfVectorizer
vec=TfidfVectorizer()
train_data=vec.fit_transform(tweets)
train_data
# Out:
# <62541x21149 sparse matrix of type '<class 'numpy.float64'>'
# 	with 680531 stored elements in Compressed Sparse Row format>

# %%
train_data
# Out:
# (62541, 21149)

# %%
y=df['target'].values
y
# Out:
# array([1, 1, 1, ..., 1, 1, 0], dtype=int64)

# %%
#trainingg and testing data spliting
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(train_data,y,test_size=0.30,random_state=42)

# %%
list(train_data[0])
# Out:
# <1x21149 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>

# %%
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
import scikitplot as skplt
from sklearn.metrics import classification_report

# %% [markdown]
# Model building

# %%
#support vector machine 
svm_model=SVC()
svm_model.fit(x_train, y_train)
y_pred = svm_model.predict(x_test)
print(classification_report(y_test,y_pred))
skplt.metrics.plot_confusion_matrix(y_test,y_pred,figsize=(4,4),
                                    title_fontsize=14,text_fontsize=10,cmap=plt.cm.Blues,title=svm_model)

# %%
#naive bayes multinomial
nb_model=MultinomialNB()
nb_model.fit(x_train, y_train)
y_pred = nb_model.predict(x_test)
print(classification_report(y_test,y_pred))
skplt.metrics.plot_confusion_matrix(y_test,y_pred,figsize=(4,4),
                                    title_fontsize=14,text_fontsize=10,cmap=plt.cm.Blues,title=nb_model)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.73      0.89      0.80      6827
#            0       0.88      0.63      0.73      5558
#            1       0.78      0.80      0.79      6378
#
#     accuracy                           0.78     18763
#    macro avg       0.80      0.77      0.77     18763
# weighted avg       0.79      0.78      0.78     18763
# <AxesSubplot:title={'center':'MultinomialNB()'}, xlabel='Predicted label', ylabel='True label'>

# %%
#KNN
knn_model=KNeighborsClassifier(n_neighbors=5)
knn_model.fit(x_train, y_train)
y_pred = knn_model.predict(x_test)
print(classification_report(y_test,y_pred))
skplt.metrics.plot_confusion_matrix(y_test,y_pred,figsize=(4,4),title_fontsize=14,
                                    text_fontsize=10,cmap=plt.cm.Blues,title=knn_model)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.95      0.78      0.85      6827
#            0       0.98      0.76      0.86      5558
#            1       0.70      0.96      0.81      6378
#
#     accuracy                           0.84     18763
#    macro avg       0.87      0.83      0.84     18763
# weighted avg       0.87      0.84      0.84     18763
# <AxesSubplot:title={'center':'KNeighborsClassifier()'}, xlabel='Predicted label', ylabel='True label'>

# %%
#Random Forest
rf_model=RandomForestClassifier()
rf_model.fit(x_train, y_train)
y_pred = rf_model.predict(x_test)
print(classification_report(y_test,y_pred))
skplt.metrics.plot_confusion_matrix(y_test,y_pred,figsize=(4,4),
                                    title_fontsize=14,text_fontsize=10,cmap=plt.cm.Blues,title=rf_model)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.94      0.93      0.94      6827
#            0       0.90      0.93      0.91      5558
#            1       0.93      0.92      0.93      6378
#
#     accuracy                           0.93     18763
#    macro avg       0.93      0.93      0.93     18763
# weighted avg       0.93      0.93      0.93     18763
# <AxesSubplot:title={'center':'RandomForestClassifier()'}, xlabel='Predicted label', ylabel='True label'>

# %%
#Decision Tree
df_model=DecisionTreeClassifier()
dt = df_model.fit(x_train, y_train)
y_pred = df_model.predict(x_test)
print(classification_report(y_test,y_pred))
skplt.metrics.plot_confusion_matrix(y_test,y_pred,figsize=(4,4),
                                    title_fontsize=14,text_fontsize=10,cmap=plt.cm.Blues,title=df_model)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.88      0.85      0.86      6827
#            0       0.80      0.84      0.82      5558
#            1       0.85      0.84      0.84      6378
#
#     accuracy                           0.84     18763
#    macro avg       0.84      0.84      0.84     18763
# weighted avg       0.84      0.84      0.84     18763
# <AxesSubplot:title={'center':'DecisionTreeClassifier()'}, xlabel='Predicted label', ylabel='True label'>
